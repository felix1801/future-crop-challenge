# %%
import os
import pandas as pd

# %%
data_path = os.path.join("..", "data", "01_raw")

# %% [markdown]
# sample_submission.csv

# %%
sample_submission_df = pd.read_csv(os.path.join(data_path, 'sample_submission.csv'))
sample_submission_df.head()
# Out:
#        ID      yield
# 0  349719   1.586834
# 1  349720  16.060235
# 2  349721   3.783943
# 3  349722  16.078949
# 4  349723  18.245241

# %% [markdown]
# pr_maize_train.parquet

# %%
pr_maize_train_df = pd.read_parquet(os.path.join(data_path, 'pr_maize_train.parquet'))
pr_maize_train_df.head()
# Out:
#      crop   year     lon    lat variable         0         1         2  \
# ID
# 0   maize  381.0 -122.25  48.25       pr  0.000227  0.000149  0.000017
# 1   maize  381.0 -122.25  48.75       pr  0.000242  0.000128  0.000000
# 2   maize  381.0 -122.25  49.25       pr  0.000483  0.000240  0.000010
# 3   maize  381.0 -116.75  43.25       pr  0.000000  0.000016  0.000000
# 4   maize  381.0 -116.75  43.75       pr  0.000015  0.000009  0.000000
#
#            3         4  ...       230       231       232       233       234  \
# ID                      ...
# 0   0.000000  0.000021  ...  0.000169  0.000131  0.000122  0.000011  0.000396
# 1   0.000000  0.000000  ...  0.000150  0.000137  0.000095  0.000009  0.000329
# 2   0.000029  0.000000  ...  0.000229  0.000201  0.000159  0.000038  0.000693
# 3   0.000000  0.000000  ...  0.000148  0.000041  0.000129  0.000072  0.000032
# 4   0.000000  0.000000  ...  0.000127  0.000026  0.000165  0.000036  0.000000
#
# ...

# %% [markdown]
# rsds_maize_train.parquet

# %%
rsds_maize_train_df = pd.read_parquet(os.path.join(data_path, 'rsds_maize_train.parquet'))
rsds_maize_train_df.head()
# Out:
#      crop   year     lon    lat variable           0          1          2  \
# ID
# 0   maize  381.0 -122.25  48.25     rsds   22.239260   98.14866   89.82650
# 1   maize  381.0 -122.25  48.75     rsds   23.723572  111.22441   84.09130
# 2   maize  381.0 -122.25  49.25     rsds   19.897753  112.63099   90.40647
# 3   maize  381.0 -116.75  43.25     rsds  142.693160  170.25294  292.77603
# 4   maize  381.0 -116.75  43.75     rsds  139.742070  197.55670  291.95795
#
#             3          4  ...        230        231        232        233  \
# ID                        ...
# 0   172.92941  117.21696  ...  26.623010  24.254791  31.233927  25.502360
# 1   181.26122  158.71701  ...  29.083282  32.876556  27.306137  31.279488
# 2   186.77657  158.62979  ...  24.836405  29.833637  25.043694  25.599792
# 3   185.90144  290.82086  ...  26.691336  64.657330  54.577854  81.616940
# 4   198.49315  287.02582  ...  19.430513  63.059586  23.625593  77.765810
#
# ...

# %% [markdown]
# soil_co2_maize_train.parquet

# %%
soil_co2_maize_train_df = pd.read_parquet(os.path.join(data_path, 'soil_co2_maize_train.parquet'))
soil_co2_maize_train_df.head()
# Out:
#      crop   year     lon    lat  texture_class  real_year     co2    nitrogen
# ID
# 0   maize  381.0 -122.25  48.25            9.0       1982  340.79  186.110992
# 1   maize  381.0 -122.25  48.75            9.0       1982  340.79  186.110992
# 2   maize  381.0 -122.25  49.25            9.0       1982  340.79  184.934006
# 3   maize  381.0 -116.75  43.25            9.0       1982  340.79  186.110992
# 4   maize  381.0 -116.75  43.75           10.0       1982  340.79  186.110992

# %% [markdown]
# tas_maize_train.parquet

# %%
tas_maize_train_df = pd.read_parquet(os.path.join(data_path, 'tas_maize_train.parquet'))
tas_maize_train_df.head()
# Out:
#      crop   year     lon    lat variable          0          1          2  \
# ID
# 0   maize  381.0 -122.25  48.25      tas  12.068207  11.320251  10.729309
# 1   maize  381.0 -122.25  48.75      tas  11.162567  10.727692   9.408691
# 2   maize  381.0 -122.25  49.25      tas  10.052032   9.490295   8.935791
# 3   maize  381.0 -116.75  43.25      tas   6.619141   9.724518  12.369080
# 4   maize  381.0 -116.75  43.75      tas   7.945373  11.088287  13.964020
#
#             3          4  ...       230       231       232       233  \
# ID                        ...
# 0   13.520142  13.068573  ...  7.912201  6.742889  5.943817  4.408508
# 1   11.815643  12.176636  ...  5.996063  4.943970  4.520538  2.477722
# 2   10.782318  10.574158  ...  4.769775  4.041809  3.560150  0.440735
# 3   16.230103   6.655975  ...  1.733643  1.555267  5.571625  4.652588
# 4   17.795990   9.634491  ...  4.399261  1.522736  7.614075  6.465118
#
#          234       235       236       237       238       239
# ...

# %% [markdown]
# tasmax_maize_train.parquet

# %%
tasmax_maize_train_df = pd.read_parquet(os.path.join(data_path, 'tasmax_maize_train.parquet'))
tasmax_maize_train_df.head()
# Out:
#      crop   year     lon    lat variable          0          1          2  \
# ID
# 0   maize  381.0 -122.25  48.25   tasmax  13.409790  12.907227  13.133698
# 1   maize  381.0 -122.25  48.75   tasmax  12.579864  12.938599  11.560303
# 2   maize  381.0 -122.25  49.25   tasmax  11.766296  10.932282  11.074890
# 3   maize  381.0 -116.75  43.25   tasmax  13.963318  15.140595  25.563995
# 4   maize  381.0 -116.75  43.75   tasmax  15.875732  15.791626  26.370514
#
#             3          4  ...        230       231        232       233  \
# ID                        ...
# 0   21.765290  21.101470  ...  12.037170  8.151184   7.101746  6.722595
# 1   20.019104  19.028107  ...   9.871307  6.449463   5.956970  5.927521
# 2   18.851715  18.133148  ...   8.011749  5.000092   4.875458  3.982117
# 3   23.612670  17.166656  ...   4.970550  5.634003  10.708343  8.829498
# 4   24.791412  20.695374  ...   7.969482  6.289002  11.024811  9.835419
#
# ...

# %% [markdown]
# tasmin_maize_train.parquet

# %%
tasmin_maize_train_df = pd.read_parquet(os.path.join(data_path, 'tasmin_maize_train.parquet'))
tasmin_maize_train_df.head()
# Out:
#      crop   year     lon    lat variable          0         1         2  \
# ID
# 0   maize  381.0 -122.25  48.25   tasmin  11.425720  9.720184  8.797363
# 1   maize  381.0 -122.25  48.75   tasmin  10.503540  8.225616  7.218658
# 2   maize  381.0 -122.25  49.25   tasmin   9.392944  6.963257  7.080444
# 3   maize  381.0 -116.75  43.25   tasmin   1.854248  4.965301  2.853577
# 4   maize  381.0 -116.75  43.75   tasmin   2.182892  6.478790  5.627441
#
#             3         4  ...       230       231       232       233  \
# ID                       ...
# 0    9.813477  7.725922  ...  4.418304  5.219177  4.878052  2.008789
# 1    8.419556  6.394257  ...  2.597534  3.518433  3.512909 -1.089630
# 2    7.627106  4.642517  ...  2.406891  2.892670  2.636230 -3.990051
# 3   10.142212 -1.015503  ... -2.417999 -3.596527 -0.861877 -0.013489
# 4   12.044403  1.348083  ... -0.287292 -2.437561  1.140381  1.394714
#
#          234       235       236       237       238       239
# ID
# ...

# %% [markdown]
# train_solutions_maize.parquet

# %%
train_solutions_maize_df = pd.read_parquet(os.path.join(data_path, 'train_solutions_maize.parquet'))
train_solutions_maize_df.head()
# Out:
#     yield
# ID
# 0   5.595
# 1   5.895
# 2   3.023
# 3   2.071
# 4   2.239
